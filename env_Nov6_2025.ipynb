# %% [markdown]
# <a href="https://colab.research.google.com/github/yufanlili211/master_thesis/blob/main/env_Nov6_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Path and version numbers for python
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.12.12

# %%
# clean the path for environment for keeping one python version later
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# install miniconda, latest version

# in terminal
# %%bash
MINICONDA_INSTALLER_SCRIPT=Miniconda3-latest-Linux-x86_64.sh
MINICONDA_PREFIX=/usr/local
# Clean up any previous downloads
rm -f $MINICONDA_INSTALLER_SCRIPT

wget https://repo.anaconda.com/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# --2025-12-05 10:04:13--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 157891003 (151M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
#      0K .......... .......... .......... .......... ..........  0% 92.8M 2s
#     50K .......... .......... .......... .......... ..........  0% 3.40M 23s
#    100K .......... .......... .......... .......... ..........  0% 4.81M 26s
#    150K .......... .......... .......... .......... ..........  0% 4.16M 28s
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# !conda --version
# Out:
# /usr/local/bin/conda
# conda 25.9.1

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python312.zip',
#  '/usr/lib/python3.12',
#  '/usr/lib/python3.12/lib-dynload',
#  '',
#  '/usr/local/lib/python3.12/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.12/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# python version - 3.9
# CANYAenv
# terminal
# %%bash
source /usr/local/etc/profile.d/conda.sh
conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
conda create -n canyaenv python=3.9 --yes
conda activate canyaenv
# Out:
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/canyaenv
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     pip-25.3                   |     pyhc872135_0         1.1 MB
#     python-3.9.25              |       h0dcde21_1        23.0 MB
#     setuptools-80.9.0          |   py39h06a4308_0         1.4 MB
#     wheel-0.45.1               |   py39h06a4308_0         114 KB
# ...

# %%
# !/usr/local/envs/canyaenv/bin/python --version
# Out:
# Python 3.9.25

# %%
# install CANYA and dependencies
# !/usr/local/envs/canyaenv/bin/pip install --no-cache-dir https://github.com/lehner-lab/canya/tarball/master
# Out:
# ...
#      | 1.8 MB 11.4 MB/s 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# INFO: pip is looking at multiple versions of grpcio to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 38.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 253.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.4/458.4 MB 82.8 MB/s  0:00:05
# ...

# %%
# check installment
# !/usr/local/envs/canyaenv/bin/python -c "import canya; print(canya.__file__)"
# Out:
# /usr/local/envs/canyaenv/lib/python3.9/site-packages/canya/__init__.py

# %%
# run example data

# download
# !wget https://raw.githubusercontent.com/lehner-lab/canya/main/example_data/example.txt
# Out:
# --2025-12-05 10:09:34--  https://raw.githubusercontent.com/lehner-lab/canya/main/example_data/example.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10105 (9.9K) [text/plain]
# Saving to: ‘example.txt’
#
# example.txt         100%[===================>]   9.87K  --.-KB/s    in 0s
#
# 2025-12-05 10:09:35 (95.0 MB/s) - ‘example.txt’ saved [10105/10105]

# %%
# in canyaenv, run canya,default mode, use model_weights1
# !/usr/local/envs/canyaenv/bin/canya --input example.txt --output example_output_01.txt
# Out:
# /usr/local/envs/canyaenv/lib/python3.9/site-packages/canya/__main__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-12-05 12:33:50.969118: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-05 12:33:50.969158: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# check the output
# !cat example_output_01.txt
# Out:
# seqid	CANYA
# sqid|1	0.21099510788917542
# sqid|10	0.2329900562763214
# sqid|100	0.11794668436050415
# sqid|101	0.16522708535194397
# sqid|102	0.39740636944770813
# sqid|103	0.4148760139942169
# sqid|104	0.19711104035377502
# sqid|105	0.5431725382804871
# sqid|106	0.4319019913673401
# sqid|107	0.5208452939987183
# sqid|108	0.2202301025390625
# sqid|109	0.3501023054122925
# sqid|11	0.29838448762893677
# sqid|110	0.15141448378562927
# sqid|111	0.12828052043914795
# sqid|112	0.63234543800354
# sqid|113	0.7100270390510559
# sqid|114	0.26897168159484863
# sqid|115	0.5791482925415039
# sqid|116	0.37565478682518005
# sqid|117	0.1525144875049591
# sqid|118	0.22415468096733093
# sqid|119	0.5637924075126648
# sqid|12	0.5439618825912476
# sqid|120	0.5976128578186035
# sqid|121	0.2108466625213623
# sqid|122	0.494452565908432
# sqid|123	0.2188478708267212
# sqid|124	0.16074109077453613
# sqid|125	0.18992936611175537
# sqid|126	0.13518616557121277
# sqid|127	0.39815714955329895
# ...

# %%
# use esemble mode, use model_weights1 to 10, no summarzie
# !/usr/local/envs/canyaenv/bin/canya --input example.txt --output example_output_02.txt --mode ensemble
# Out:
# /usr/local/envs/canyaenv/lib/python3.9/site-packages/canya/__main__.py:3: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# 2025-12-05 12:27:19.803215: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-05 12:27:19.803265: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# !cat example_output_02.txt
# Out:
# seqid	seq	pos	pred	sd
# sqid|1	KLSGFKFEVTCDGHEFWGHP	1:20	0.24850748777389525	0.0392657619554468
# sqid|2	NYYLVCCCKREQRLCTVGIT	1:20	0.5156873852014542	0.104153815543636
# sqid|3	NFAYCYFFS	1:9	0.6456234306097031	0.0730414641126536
# sqid|4	TMNTLILCHFFWLDETISPM	1:20	0.44157094061374663	0.0325626761633735
# sqid|5	TAEIVLRMLTFPASSVRS	1:18	0.18115820586681367	0.022156391018038485
# sqid|6	TSHAVFNTVINLVVFVDQHC	1:20	0.7949626743793488	0.0546425489546405
# sqid|7	TCLRACVHLVNYGVDMFSDK	1:20	0.3409681558609009	0.040843813670422974
# sqid|8	TFYLFSRGSSLEIWG	1:15	0.2254566490650177	0.02278955573092126
# sqid|9	TFYVIYLEKNHYAG	1:14	0.4204034596681595	0.04000379935949921
# sqid|10	SRLQLNWLQPRWY	1:13	0.20733198821544646	0.024687991902613723
# sqid|11	SMSCVVHRGSSASCWMFYRN	1:20	0.3037240833044052	0.027714087696880062
# sqid|12	SILIRLIISTINCCVNNVAF	1:20	0.6121523916721344	0.0812049047731655
# sqid|13	SLIRLCVAVTSTSNPGWPLL	1:20	0.2568145036697388	0.042811215992598434
# ...
